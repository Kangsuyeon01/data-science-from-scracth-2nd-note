# %% [markdown]
# #  IDEA LAB 6th Weekly Seminar Conference Code File
# ## Logistic regression from scratch in Python
# writer: Su-Yeon Kang
#
# 2022.08.09

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [[2,0],[4,0],[6,0],[8,1],[10,1],[12,1],[14,1]]

x_data = [i[0] for i in data]
y_data = [i[1] for i in data]

#그래프로 나타내기
plt.scatter(x_data, y_data, c = 'b')
plt.xlim(0,15)
plt.ylim(-.1,1.1)
plt.show()

# %%
#기울기 w와 절편 b 값 초기화

w = 0
b = 0
lr = 0.05 # learning rate

# %% [markdown]
# ### 시그모이드 함수 정의
# ![image.png](attachment:image.png)

# %%
def sigmoid(x):
    return 1 / (1 + np.e ** (-x))

# %% [markdown]
# ### 경사하강법 실행
# #### 로지스틱 함수에서 손실함수는 이진 교차 엔트로피 손실함수 사용
# #### 경사하강법을 사용하기위해서는 함수 값에 대한 미분이 필요하다.
#
# ![image-2.png](attachment:image-2.png)

# %%
#경사하강법 실행
#1000번 반복할 때 마다 각 x_data값에 대한 현재의  a값, b값 출력

for i in range(2001):
    for x_data, y_data in data:
        # a에 관한 편미분. 앞서 정의한 sigmoid 함수 사용
        a_diff = x_data*(sigmoid(a*x_data + b) - y_data)
        # b에 관한 편미분
        b_diff = sigmoid(a*x_data + b) - y_data
        # a를 업데이트 하기 위해 a - diff에 학습률 lr을 곱한 값을 a에서 뺌
        a = a - lr * a_diff
        # b를 업데이트 하기 위해 b - diff에 학습률 lr을 곱한 값을 b에서 뺌
        b = b - lr * b_diff
        if i % 1000 == 0:
            print("epoch = %f, 기울기 =%.04f, 절편=%04f" % (i,a,b))
# Out:
# epoch = 0.000000, 기울기 =1.8090, 절편=-0.048920
# epoch = 0.000000, 기울기 =1.6091, 절편=-0.098883
# epoch = 0.000000, 기울기 =1.3091, 절편=-0.148879
# epoch = 0.000000, 기울기 =1.3091, 절편=-0.148877
# epoch = 0.000000, 기울기 =1.3092, 절편=-0.148877
# epoch = 0.000000, 기울기 =1.3092, 절편=-0.148877
# epoch = 0.000000, 기울기 =1.3092, 절편=-0.148877
# epoch = 1000.000000, 기울기 =1.5010, 절편=-9.964109
# epoch = 1000.000000, 기울기 =1.4973, 절편=-9.965044
# epoch = 1000.000000, 기울기 =1.4155, 절편=-9.978677
# epoch = 1000.000000, 기울기 =1.4982, 절편=-9.968345
# epoch = 1000.000000, 기울기 =1.5015, 절편=-9.968015
# epoch = 1000.000000, 기울기 =1.5017, 절편=-9.967999
# epoch = 1000.000000, 기울기 =1.5017, 절편=-9.967998
# epoch = 2000.000000, 기울기 =1.9084, 절편=-12.963251
# epoch = 2000.000000, 기울기 =1.9075, 절편=-12.963492
# epoch = 2000.000000, 기울기 =1.8536, 절편=-12.972475
# epoch = 2000.000000, 기울기 =1.9076, 절편=-12.965717
# epoch = 2000.000000, 기울기 =1.9087, 절편=-12.965607
# epoch = 2000.000000, 기울기 =1.9088, 절편=-12.965604
# epoch = 2000.000000, 기울기 =1.9088, 절편=-12.965604

# %%
plt.scatter(x_data, y_data)
plt.xlim(0, 15)
plt.ylim(-.1, 1.1)
x_range = (np.arange(0, 15, 0.1)) # 그래프로 나타낼 x 값의 범위 정하기
plt.plot(np.arange(0, 15, 0.1), np.array([sigmoid(a * x + b) for x in x_range]))
plt.show()
